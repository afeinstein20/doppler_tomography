# %%
import numpy as np
from dt_code import DopplerTomography
import matplotlib.pyplot as plt
from astropy import units as u
from astropy.table import Table
from astropy.io import ascii
from astropy.time import Time
from scipy.optimize import minimize
# Out:
# WARNING: leap-second auto-update failed due to the following exception: ValueError("Malformed URL: '//anaconda3/lib/python3.7/site-packages/astropy/utils/iers/data/Leap_Second.dat'") [astropy.time.core]
# WARNING: AstropyDeprecationWarning: block_reduce was moved to the astropy.nddata.blocks module.  Please update your import statement. [astropy.nddata.utils]
# WARNING: AstropyDeprecationWarning: block_replicate was moved to the astropy.nddata.blocks module.  Please update your import statement. [astropy.nddata.utils]

# %%
dt_obj = DopplerTomography(fn_dir='/Users/arcticfox/Downloads/gemini_data_2021/',
                           reload=True)

# %%
dt_obj.science_frames.shape
# Out:
# (43, 4608, 2088)

# %%
plt.imshow(dt_obj.med_flat)

# %%
dt_obj.barycentric_correction('V1298 Tau', observatory='keck')

# %%
ref_file = '/Users/arcticfox/Documents/atmospheres/v1298tau/data/N20200122G0066m.fits'
dt_obj.pipeline_reference(ref_file)

# %%
dt_obj.extract_data()
# Out:
# 100%|██████████| 43/43 [01:04<00:00,  1.39s/it]

# %%
dt_obj.spectra.shape
# Out:
# (43, 26, 4608)

# %%
ind = 11
for i in range(len(dt_obj.times)):
    plt.plot(dt_obj.corrected_wavelengths[i][ind], 
             dt_obj.corrected_spectra[i][ind])
    plt.show()

# %%
dt_obj.wavelengths.shape, dt_obj.corrected_spectra.shape, dt_obj.orders.shape
# Out:
# ((43, 26, 4608), (43, 26, 3908), (43, 26, 3908))

# %%
3908*3
# Out:
# 11724
